# %% [markdown]
# # Run script to find number of images containing images
#
# Activate the virtual environment
#
# ```bash
# !conda activate mega_env
# ```

# %%
# define file location
image_folder = "/Volumes/GARDEPRO/DCIM/"

# %%
# !python image_process_new.py "/Volumes/GARDEPRO/DCIM/118MEDIA" "/Users/kline.377/Desktop/CT02/animals_detected"
# Out:
# Processing images 1–100 of 999
# Model v5a.0.1 already exists and is valid at /var/folders/vb/jnfq7cgj3nnfyd3llkzll1k40000gp/T/megadetector_models/md_v5a.0.1.pt
# PyTorch reports 0 available CUDA devices
# PyTorch reports Metal Performance Shaders are available
# GPU available: True
# Loading PT detector with compatibility mode classic
# Loaded image size 1280 from model metadata
# Fusing layers...
# Fusing layers...
# Model summary: 733 layers, 140054656 parameters, 0 gradients, 208.8 GFLOPs
# Model summary: 733 layers, 140054656 parameters, 0 gradients, 208.8 GFLOPs
# Loaded model in 3.81 seconds
# ...
# 100%|█████████████████████████████████████████| 100/100 [00:20<00:00,  4.86it/s]
#
# Processing images 101–200 of 999
# Model v5a.0.1 already exists and is valid at /var/folders/vb/jnfq7cgj3nnfyd3llkzll1k40000gp/T/megadetector_models/md_v5a.0.1.pt
# PyTorch reports 0 available CUDA devices
# PyTorch reports Metal Performance Shaders are available
# GPU available: True
# ...
